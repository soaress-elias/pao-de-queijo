# %%
import duckdb

# %%
conexao = duckdb.connect(database='dados_duckdb.db', read_only=False)

# %%
df = conexao.execute("""
SELECT * FROM 
                     (SELECT *, ROW_NUMBER() OVER (PARTITION BY NATBR ORDER BY data_ingestao DESC) AS row 
                     FROM bronze_z0019
                     WHERE data_ingestao >= '2026-01-21')
                     WHERE row = 1
""").fetchdf()
df.head(10)

# %%
df_final = df.drop(columns=['nome_arquivo', 'data_ingestao', 'row'])
df_final = df_final.rename(columns={"NATBR": "id"})
df_final = df_final.rename(columns={"MAKTX": "nm_produto"})
df_final = df_final.rename(columns={"WERKS": "id_categoria"})
df_final = df_final.rename(columns={"MAINS": "id_fornecedor"})
df_final = df_final.rename(columns={"LABST": "vl_preco"})
df_final.head(10)

# %%
df_final.dtypes

# %%
df2 = df_final
df2 = df2.astype(
    {
        'id': int,
        'nm_produto': str,
        'id_categoria': str,
        'id_fornecedor': int,
        'vl_preco': float
    }
)

df2.dtypes

# %%
#criação da tabela na camada Silver ("produtos")
conexao.execute("""
CREATE TABLE IF NOT EXISTS produtos (
                id BIGINT,
                nm_produto TEXT,
                id_categoria TEXT,
                id_fornecedor BIGINT,
                vl_preco FLOAT
                )
""")

# %%
df2.head(10)

# %%
#inserção de dados em tabela da camada Silver (tabela "produtos")
conexao.execute("INSERT INTO produtos SELECT * FROM df2")

# %%
df_resultado = conexao.execute("SELECT * FROM produtos").fetchdf()
df_resultado.head(10)

# %%
conexao.close()
